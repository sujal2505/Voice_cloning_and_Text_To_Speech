# %%
import os
import numpy as np
import soundfile as sf
from TTS.api import TTS

# %%
TTS.list_models()

model_name = "tts_models/multilingual/multi-dataset/xtts_v2"

tts = TTS(model_name)

audio = "WhatsApp Audio 2025-10-03 at 11.36.29_92c1b1dc.wav"  

text = input("Enter the text you want to convert to speech: ")

tts.tts_to_file(
    text=text,
    speaker_wav=audio,
    language="en",
    file_path="output_cloned.wav"
)
import IPython.display as ipd
ipd.Audio("output_cloned.wav")
# Out:
# Enter the text you want to convert to speech:  This is my first deep learning project using voice cloning.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
TTS.list_models()

model_name = "tts_models/multilingual/multi-dataset/xtts_v2"

tts = TTS(model_name)

audio = "medieval-gamer-voice-darkness-hunts-us-what-youx27ve-learned-stay-226596.wav"  

text = "नमस्ते, यह हिंदी आवाज़ क्लोनिंग का उदाहरण है।"

tts.tts_to_file(
    text=text,
    speaker_wav=audio,
    language="hi",
    file_path="output_hindi.wav"
)
import IPython.display as ipd
ipd.Audio("output_hindi.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import time

start = time.time()
tts.tts_to_file(
    text=text,
    speaker_wav=audio,
    language="en",
    file_path="output_cloned.wav"
)
print(f"⏱ TTS generation time: {time.time() - start:.2f} sec")
# Out:
# ⏱ TTS generation time: 83.30 sec
